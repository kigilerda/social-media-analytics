# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/data_base.csv") 
df.head(3)
# Out:
#    id_post                       date  \
# 0    14381  2026-02-02 13:31:57+00:00
# 1    14380  2026-02-02 10:49:42+00:00
# 2    14376  2026-02-02 10:01:14+00:00
#
#                                                 text   views  reactions  \
# 0  Меню «Пуск» в Windows 11 [превратили](https://...   74536       1064
# 1  В Москве робота заметили за уборкой снега. \n\...  110566       1442
# 2  В Steam вышел хоррор The 18th Attic — в нем ну...  104438        675
#
#    comments
# 0         0
# 1         0
# 2         0

# %%
df.shape, df.columns
# Out:
# ((3351, 6),
#  Index(['id_post', 'date', 'text', 'views', 'reactions', 'comments'], dtype='str'))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3351 entries, 0 to 3350
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_post    3351 non-null   int64
#  1   date       3351 non-null   str
#  2   text       3351 non-null   str
#  3   views      3351 non-null   int64
#  4   reactions  3351 non-null   int64
#  5   comments   3351 non-null   int64
# dtypes: int64(4), str(2)
# memory usage: 157.2 KB

# %%
df.isna().mean().sort_values(ascending=False).head(10)
# Out:
# id_post      0.0
# date         0.0
# text         0.0
# views        0.0
# reactions    0.0
# comments     0.0
# dtype: float64

# %%
df0 = df.copy()

# %%
df0["date"] = pd.to_datetime(df0["date"], errors="coerce", utc=True)

# %%
before = len(df0)
df0 = df0[df0["views"].fillna(0) > 0].copy()
df0 = df0[df0["reactions"].fillna(0) >= 0].copy()
df0 = df0.dropna(subset=["date"])

# %%
after = len(df0)
before, after, before - after
# Out:
# (3351, 3351, 0)

# %%
df0["engagement"].describe(percentiles=[0.5, 0.75, 0.9, 0.95, 0.97, 0.99])
# Out:
# count    3351.000000
# mean        0.007431
# std         0.006488
# min         0.000000
# 50%         0.006440
# 75%         0.009592
# 90%         0.012574
# 95%         0.014752
# 97%         0.016730
# 99%         0.020276
# max         0.302003
# Name: engagement, dtype: float64
